# %% [markdown]
# # Deep Learning

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow.keras.datasets as tfds
import numpy as np

# %%
(x_train,y_train),(x_test,y_test) = tfds.mnist.load_data()

print(f'panjang x train : {len(x_train)}',
f'panjang y train : {len(y_train)}',
f'panjang x test : {len(x_test)}',
f'panjang y test : {len(y_test)}')
# Out:
# panjang x train : 60000 panjang y train : 60000 panjang x test : 10000 panjang y test : 10000

# %%
num_class = 10
y_train = tf.keras.utils.to_categorical(y_train, num_class)
y_test = tf.keras.utils.to_categorical(y_test, num_class)

# %%
plt.imshow(x_train[69])

# %%
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# %%
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %%
model = tf.keras.Sequential([tf.keras.layers.Dense(32, activation='relu',input_dim=784),
tf.keras.layers.Dense(num_class, activation='softmax')])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 32)                25120
#
#  dense_13 (Dense)            (None, 10)                330
#
# ...
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss = tf.keras.losses.categorical_crossentropy,
    metrics = ['accuracy']
)

# %%
history = model.fit(
    x = x_train, y =y_train,
    validation_data=(x_test,y_test),
    epochs=10,
    steps_per_epoch=500,
    verbose=1
)
# Out:
# Epoch 1/10
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4993 - accuracy: 0.8663 - val_loss: 0.2717 - val_accuracy: 0.9222
# Epoch 2/10
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2549 - accuracy: 0.9287 - val_loss: 0.2256 - val_accuracy: 0.9365
# Epoch 3/10
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2115 - accuracy: 0.9413 - val_loss: 0.2010 - val_accuracy: 0.9445
# Epoch 4/10
# 500/500 [==============================] - 1s 1ms/step - loss: 0.1830 - accuracy: 0.9484 - val_loss: 0.1757 - val_accuracy: 0.9493
# Epoch 5/10
# 500/500 [==============================] - 1s 1ms/step - loss: 0.1622 - accuracy: 0.9542 - val_loss: 0.1587 - val_accuracy: 0.9525
# Epoch 6/10
# 500/500 [==============================] - 1s 2ms/step - loss: 0.1455 - accuracy: 0.9588 - val_loss: 0.1487 - val_accuracy: 0.9552
# Epoch 7/10
# ...

# %%
plt.figure(1,figsize= (5,5))
plt.plot(range(len(history.history['accuracy'])),history.history['accuracy'],label='training')
plt.plot(range(len(history.history['val_accuracy'])),history.history['val_accuracy'],label='validation')
plt.legend()
plt.show()

# %%
model.save('model/model1.h5')

# %%
saved_model = tf.keras.models.load_model('model/model1.h5')

# %%
saved_model.evaluate(x_test,y_test,batch_size=32)
# Out:
# 313/313 [==============================] - 0s 693us/step - loss: 0.1258 - accuracy: 0.9619
# [0.12581023573875427, 0.961899995803833]

# %%
hasil = saved_model.predict(x_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
hasil.shape
# Out:
# (10000, 10)

# %%
np.argmax(hasil[1])
# Out:
# 2
